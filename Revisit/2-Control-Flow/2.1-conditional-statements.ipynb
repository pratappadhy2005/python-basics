# %%
## If and elif Statement
a=5
if a>5:
    print("a is greater than 5")
elif a==5:
    print("a is equal to 5")
else:
    print("a is less than 5")
# Out:
# a is equal to 5

# %%
## Nested If Statement
## number even, ood or negative
num=int(input("Enter a number: "))
if num>0:
    if num%2==0:
        print("Even positive number")
    else:
        print("Odd positive number")
elif num<0:
    if num%2==0:
        print("Even negative number")
    else:
        print("Odd negative number")
else:
    print("Zero")
# Out:
# Even positive number

# %%
## Practical Example
## Need to determine whether a year is a leap year
year= int(input("Enter a year: "))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print("Leap year")
        else:
            print("Not a leap year")
    else:
        print("Leap year")
else:
    print("Not a leap year")
# Out:
# Not a leap year

# %%
## Assignments
## Simple Calculator
first_number=input("Enter the first number: ")
second_number=input("Enter the second number: ")
operation_type=input("Enter the operation type: ")

if operation_type=="add":
    result=float(first_number)+float(second_number)
    print(result)

elif operation_type=="subtract":
    result=float(first_number)-float(second_number)
    print(result)
    
elif operation_type=="multiply":
    result=float(first_number)*float(second_number)
    print(result)
    
elif operation_type=="divide":
    result=float(first_number)/float(second_number)
    print(result)
    
else:
    print("Invalid operation type")
# Out:
# Invalid operation type
