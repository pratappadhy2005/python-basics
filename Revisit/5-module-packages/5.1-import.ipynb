# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
from math import sqrt, pi
sqrt(9)
pi
# Out:
# 3.141592653589793

# %%
import numpy as np
np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
from math import *
print(sqrt(9))
print(pi)
# Out:
# 3.0
# 3.141592653589793

# %%
from package.maths import add
print(add(2, 3))
# Out:
# 5

# %%
from package import maths
print(maths.add(2, 3))
# Out:
# 5
