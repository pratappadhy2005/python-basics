# %%
## Integer example
age=35
type(age)
# Out:
# int

# %%
## Float example
width=5.5
type(width)
# Out:
# float

# %%
## String datatype example
name='Pratappadhy'
type(name)
print(name)
# Out:
# Pratappadhy

# %%
## boolean datatype example
is_true=True
print(type(is_true))
print(is_true)
# Out:
# <class 'bool'>
# True

# %%
is_false=False
print(is_false)
print(type(is_false))
# Out:
# False
# <class 'bool'>

# %%
a=10
b=10
a==b
type(a==b)
# Out:
# bool

# %%
## common errors
result="hello" + str(5)
print(result)
# Out:
# hello5

# %%
str="1.0-basic.ipynb"
str.split(".")[0]
print(str.split(".")[0])
# Out:
# 1

# %%
sugar_amount = 100
print(f"sugar_amount = {sugar_amount}")
sugar_amount = 200
print(f"sugar_amount = {sugar_amount}")
# Out:
# sugar_amount = 100
# sugar_amount = 200
