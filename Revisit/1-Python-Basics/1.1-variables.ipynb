# %%
a=100

# %%
## Declaring and assigning variables
age=32
height=6.1
name="Pratap"
is_student=True

##printing the variables
print("age : ",age)
print("Height : ",height)
print("Name : ", name)
# Out:
# age :  32
# Height :  6.1
# Name :  Pratap

# %%
## Naming convention
## Variable names should be descriptive
## They must start with a letter or an '_' and contains letter, numenr and underscores

## valid varibale names

first_name = "Pratap"
last_name = "Padhy"
## invalid variable name : 2age =  32

# %%
## Variable Types
## Python is dynamically typed, type of a variable is detrmined at runtime
age=25 #int
height=6.1 #float
is_student= True

print(type(is_student))
# Out:
# <class 'bool'>

# %%
## Type checking and Conversion
type(height)
# Out:
# float

# %%
age=25
print(type(age))

age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
height=5.11
type(height)
# Out:
# float

# %%
## Dynamic Typing
## Python allows the type of variable to change as the program execution
var=10
print(var)
print(type(var))

var = 'hello'
print(var, type(var))
# Out:
# 10
# <class 'int'>
# hello <class 'str'>

# %%
## Use Input
age= int(input("What is the age"))
print(age, type(age))
# Out:
# 12 <class 'int'>
