# %%
## Arithmetic Operators
a=10
b=15

add=a+b
sub=a-b
mul=a*b
div=a/b
floor=a//b  
modulus=a%b

print(add)
print(sub)
print(mul)
print(div)
print(floor)
print(modulus)
# Out:
# 25
# -5
# 150
# 0.6666666666666666
# 0
# 10

# %%
## Comparison Operators
## == Equality Operator
a=10
b=10

result=a==b
print(result)
# Out:
# True

# %%
str1="Hello World"
str2="Hello World"
print(str1==str2)
# Out:
# True

# %%
## Not equal operator
a=10
b=10
result=a!=b
print(result)
# Out:
# False

# %%
str3="Hello World"
str4="HEllo World"
print(str3!=str4)
# Out:
# True

# %%
## greater than operator
a=10
b=20
result=a>b
print(result)
# Out:
# False

# %%
## Less than operator
a=10
b=20
result=a<b
print(result)
# Out:
# True

# %%
## greater than or equal to operator
a=10
b=20
result=a>=b
print(result)
# Out:
# False

# %%
## less than or equal to operator
a=10
b=20
result=a<=b
print(result)
# Out:
# True

# %%
## Logical Operators
### and operator
a=True
b=False
result=a and b
print(result)

### or operator
a=True
b=False
result=a or b
print(result)

### not operator
a=True
b=False
result=not a
print(result)

## Bitwise Operators
### and operator
a=10
b=20
result=a&b
print(result)
# Out:
# False
# True
# False
# 0

# %%
## Write Simple Calculator
### Write a simple calculator that can perform addition, subtraction, multiplication, and division.
### The calculator should take two numbers as input and perform the selected operation on them.
### Display the result of the calculation.
### Handle any errors that may occur, such as division by zero.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

sum = a + b
sub = a - b
mul = a * b
div = a / b

print("Sum:", sum)
print("Subtraction:", sub)
print("Multiplication:", mul)
print("Division:", div)
# Out:
# Sum: 35
# Subtraction: -11
# Multiplication: 276
# Division: 0.5217391304347826
