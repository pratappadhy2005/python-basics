# %%
## Inheritance
## Parent Class

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    
    def get_descriptive_name(self):
        long_name = f"{self.year} {self.make} {self.model}"
        return long_name.title()


class ElectricCar(Car):
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery_size = 75
    
    def describe_battery(self):
        print(f"This car has a {self.battery_size}-kWh battery.")

# %%
elec_car = ElectricCar("Tesla","Model S",2024)
elec_car.get_descriptive_name()
elec_car.describe_battery()
# Out:
# This car has a 75-kWh battery.

# %%
## Multiple Inheritance
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def print_info(self):
        print(f"{self.name} is a {self.age} year old animal")

class Dog(Animal):
    def __init__(self, name, age):
        super().__init__(name, age)
        self.breed = "Labrador"

    def print_info(self):
        print(f"{self.name} is a {self.age} year old {self.breed}")

class Cat(Animal):
    def __init__(self, name, age):
        super().__init__(name, age)
        self.breed = "Siamese"

    def print_info(self):
        print(f"{self.name} is a {self.age} year old {self.breed}")

        super().print_info()

# %%
cat = Cat( "Siamese", 2)
cat.print_info()
# Out:
# Siamese is a 2 year old Siamese
# Siamese is a 2 year old animal
